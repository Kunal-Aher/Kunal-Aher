# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix,classification_report,r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
Task2=pd.read_excel(r"D:\kunal_cdac_blr_notes\ML\TASK_TWO.xlsx")

Task2
# Out:
#            SUMMARY OUTPUT       Unnamed: 1      Unnamed: 2  \
# 0                     NaN              NaN             NaN
# 1   Regression Statistics              NaN             NaN
# 2              Multiple R         0.993861             NaN
# 3                R Square          0.98776             NaN
# 4       Adjusted R Square         0.984539             NaN
# 5          Standard Error         3.452575             NaN
# 6            Observations               25             NaN
# 7                     NaN              NaN             NaN
# 8                   ANOVA              NaN             NaN
# 9                     NaN               df              SS
# 10             Regression                5    18277.514737
# 11               Residual               19      226.485263
# 12                  Total               24         18504.0
# 13                    NaN              NaN             NaN
# 14                    NaN     Coefficients  Standard Error
# ...

# %%
x=Task2[["rain","water","dust","air","mud"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x=Task2[["rain","water","dust","air","mud"]]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# ...

# %%
y=Task2['yield']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'yield'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)

# %%
# vif=pd.DataFrame(Task2)

# %%
vif['features']=x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF",ascending= False)
vif

# %%
coeff=model.coef_

intercept=model.intercept_
# Out:
# [ 0.11172609 -0.09376292  0.27327126  0.42684685  0.96675731]
# -39.96535179439215

# %%
coeff
# Out:
# array([ 0.11172609, -0.09376292,  0.27327126,  0.42684685,  0.96675731])

# %%
intercept
# Out:
# -39.96535179439215

# %%
line_eq=coeff*[40]+intercept
line_eq
# Out:
# array([-35.49630809, -43.71586849, -29.03450142, -22.89147787,
#         -1.29505956])

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ 55.04165058,  69.12383776, 101.19138112,  69.34844508,
#         19.90347616,  65.85964487,   7.18837672,  19.90347616])

# %%
data=pd.DataFrame({"Predicted":y_pred,"Actual":y_test})

# %%
data
# Out:
#      Predicted  Actual
# 8    55.041651      50
# 16   69.123838      75
# 0   101.191381     100
# 23   69.348445      70
# 11   19.903476      20
# 9    65.859645      70
# 13    7.188377      10
# 1    19.903476      20

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9880605806788832

# %%
mae = mean_absolute_error(y_test, y_pred) 
mse = mean_squared_error(y_test, y_pred) 
rmse = mse

# %%
rmse
# Out:
# 10.857229475310525

# %%
mae
# Out:
# 2.4882218687802755

# %%
mse
# Out:
# 10.857229475310525
