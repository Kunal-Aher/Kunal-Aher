# %%
import pandas as pd
import numpy as np
df=pd.read_csv("D:\kunal_cdac_blr_notes\Regression.csv")
df1=df.copy()

# %%
df1
# Out:
#            SUMMARY OUTPUT       Unnamed: 1      Unnamed: 2   Unnamed: 3  \
# 0                     NaN              NaN             NaN          NaN
# 1   Regression Statistics              NaN             NaN          NaN
# 2              Multiple R         0.233342             NaN          NaN
# 3                R Square      0.054448489             NaN          NaN
# 4       Adjusted R Square     -0.125656561             NaN          NaN
# 5          Standard Error      78.06231148             NaN          NaN
# 6            Observations               26             NaN          NaN
# 7                     NaN              NaN             NaN          NaN
# 8                   ANOVA              NaN             NaN          NaN
# 9                     NaN               df              SS           MS
# 10             Regression                4     7368.901427  1842.225357
# 11               Residual               21      127968.214  6093.724474
# ...

# %%
df1.drop(columns=['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df1.drop(columns=['name'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
bais=np.array([1,1,1,1])
val1=np.array([,[df1["f1"].to_numpy(),df["f2"].to_numpy(),df["f3"].to_numpy(),df["f4"].to_numpy()]])

# %%
val1

# %%
y
# Out:
# array(['Target'], dtype='<U6')

# %%
trasposeval=val1.T
trasposeval
# Out:
# array([[[10],
#         [80],
#         [ 0],
#         [20]],
#
#        [[20],
#         [90],
#         [10],
#         [ 0]],
#
#        [[ 0],
#         [20],
#         [50],
#         [50]],
#
#        [[50],
#         [ 0],
#         [20],
#         [10]],
#
#        [[65],
#         [94],
#         [19],
#         [28]],
#
#        [[80],
#         [25],
#         [32],
#         [58]],
#
#        [[25],
#         [64],
#         [95],
#         [55]],
#
#        [[85],
#         [28],
#         [62],
#         [56]],
#
#        [[40],
#         [40],
#         [49],
#         [12]],
#
#        [[20],
#         [20],
#         [87],
#         [80]],
#
#        [[94],
#         [94],
#         [84],
#         [90]],
#
#        [[25],
#         [25],
#         [55],
#         [20]],
#
#        [[64],
#         [64],
#         [28],
#         [ 0]],
#
#        [[28],
#         [49],
#         [65],
#         [94]],
#
#        [[58],
#         [87],
#         [45],
# ...

# %%
new=val1.dot(trasposeval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 new=val1.dot(trasposeval)
#
# ValueError: shapes (1,4,26) and (26,4,1) not aligned: 26 (dim 2) != 4 (dim 1)
